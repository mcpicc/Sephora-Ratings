# %% [markdown]
# ### Data Wrangling

# %%
# import libraries

import numpy as np
import pandas as pd

import string
import re

import pickle

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# import product info files
prod_info = pd.read_csv('product_info.csv')

# %%
# import review files

#reviews_1 = pd.read_csv('reviews_0_250.csv')

reviews_2 = pd.read_csv('reviews_250_500.csv')
reviews_3 = pd.read_csv('reviews_500_750.csv')
reviews_4 = pd.read_csv('reviews_750_1000.csv')
reviews_5 = pd.read_csv('reviews_1000_1500.csv')
reviews_6 = pd.read_csv('reviews_1500_end.csv')

# %%
# view product info dataframe

prod_info.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0             NaN                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive  \
# 0             NaN  ...           1            0                  0
# 1  3.4 oz/ 100 mL  ...           1            0                  0
# 2  3.4 oz/ 100 mL  ...           1            0                  0
# 3  3.4 oz/ 100 mL  ...           1            0                  0
# 4  3.4 oz/ 100 mL  ...           1            0                  0
#
#                                           highlights  primary_category  \
# 0  ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...         Fragrance
# 1  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 2  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 3  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 4  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
#
#    secondary_category  tertiary_category  child_count  child_max_price  \
# 0   Value & Gift Sets  Perfume Gift Sets            0              NaN
# 1               Women            Perfume            2             85.0
# 2               Women            Perfume            2             75.0
# 3               Women            Perfume            2             75.0
# 4               Women            Perfume            2             75.0
#
#    child_min_price
# 0              NaN
# 1             30.0
# 2             30.0
# 3             30.0
# 4             30.0
#
# [5 rows x 27 columns]

# %%
# view reviews dataframes

reviews_2.head()
# Out:
#    Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 0           0   2190293206       2             0.0          NaN
# 1           1   9113341005       5             1.0          NaN
# 2           2  23866342710       1             0.0     1.000000
# 3           3   1328806527       1             0.0     0.941176
# 4           4  31262847082       5             1.0     1.000000
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     0                         0                         0
# 1                     0                         0                         0
# 2                    13                         0                        13
# 3                    17                         1                        16
# 4                     1                         0                         1
#
#   submission_time                                        review_text  \
# 0      2023-03-19  Used to swear by this product but hate the sme...
# 1      2023-03-18  I’ve only been using this for a week and my sk...
# 2      2023-03-12  Why, why, why would you change the formula?!!!...
# 3      2023-03-12  I have used this product for years and it has ...
# 4      2023-03-09  Great product for anti-aging Also great for da...
#
#                                         review_title    skin_tone eye_color  \
# 0                                                NaN  lightMedium     brown
# 1                   More tolerable than The Ordinary         deep     brown
# 2                      New formula is awful very sad    fairLight      blue
# 3  Recently reformulated and the new formula is A...        light     brown
# 4  Must have product in my nighttime skincare rou...  lightMedium     hazel
#
#      skin_type hair_color product_id              product_name  \
# 0  combination      brown    P443842  Retinol Anti-Aging Serum
# 1       normal      black    P443842  Retinol Anti-Aging Serum
# 2  combination     blonde    P443842  Retinol Anti-Aging Serum
# 3  combination       gray    P443842  Retinol Anti-Aging Serum
# 4  combination      brown    P443842  Retinol Anti-Aging Serum
#
#        brand_name  price_usd
# 0  The INKEY List      12.99
# 1  The INKEY List      12.99
# 2  The INKEY List      12.99
# 3  The INKEY List      12.99
# 4  The INKEY List      12.99

# %%
reviews_3.head()
# Out:
#    Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 0           0   2190293206       2             0.0          NaN
# 1           1   9113341005       5             1.0          NaN
# 2           2  23866342710       1             0.0     1.000000
# 3           3   1328806527       1             0.0     0.941176
# 4           4  31262847082       5             1.0     1.000000
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     0                         0                         0
# 1                     0                         0                         0
# 2                    13                         0                        13
# 3                    17                         1                        16
# 4                     1                         0                         1
#
#   submission_time                                        review_text  \
# 0      2023-03-19  Used to swear by this product but hate the sme...
# 1      2023-03-18  I’ve only been using this for a week and my sk...
# 2      2023-03-12  Why, why, why would you change the formula?!!!...
# 3      2023-03-12  I have used this product for years and it has ...
# 4      2023-03-09  Great product for anti-aging Also great for da...
#
#                                         review_title    skin_tone eye_color  \
# 0                                                NaN  lightMedium     brown
# 1                   More tolerable than The Ordinary         deep     brown
# 2                      New formula is awful very sad    fairLight      blue
# 3  Recently reformulated and the new formula is A...        light     brown
# 4  Must have product in my nighttime skincare rou...  lightMedium     hazel
#
#      skin_type hair_color product_id              product_name  \
# 0  combination      brown    P443842  Retinol Anti-Aging Serum
# 1       normal      black    P443842  Retinol Anti-Aging Serum
# 2  combination     blonde    P443842  Retinol Anti-Aging Serum
# 3  combination       gray    P443842  Retinol Anti-Aging Serum
# 4  combination      brown    P443842  Retinol Anti-Aging Serum
#
#        brand_name  price_usd
# 0  The INKEY List      12.99
# 1  The INKEY List      12.99
# 2  The INKEY List      12.99
# 3  The INKEY List      12.99
# 4  The INKEY List      12.99

# %%
reviews_4.head()
# Out:
#    Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 0           0   2079014373       5             1.0          NaN
# 1           1  12631885517       4             1.0          NaN
# 2           2   2321761961       5             1.0          1.0
# 3           3   1380382883       4             1.0          NaN
# 4           4   8871759068       4             1.0          1.0
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     0                         0                         0
# 1                     0                         0                         0
# 2                     1                         0                         1
# 3                     0                         0                         0
# 4                     1                         0                         1
#
#   submission_time                                        review_text  \
# 0      2023-03-14  These are the only pimple patches I’ve used th...
# 1      2023-02-08  One of my ingrown hair turned inflamed and sor...
# 2      2023-02-05  I have tried 10 different acne/blemish patches...
# 3      2023-01-24  Love these for my mid-size breakouts, specifyi...
# 4      2023-01-15  Best so far - though still not particularly ef...
#
#                                         review_title  skin_tone eye_color  \
# 0                                Best Pimple Patches     medium      blue
# 1                                          It works!  mediumTan     brown
# 2  Good for a large or painful breakout! Sleep in...        NaN     hazel
# 3                            Micro tips are a plus!!      light     brown
# 4                                                NaN        NaN       NaN
#
#      skin_type hair_color product_id                product_name brand_name  \
# 0       normal        NaN    P442857  Focuspot Micro Tip Patches  Dr. Jart+
# 1  combination      black    P442857  Focuspot Micro Tip Patches  Dr. Jart+
# 2  combination     blonde    P442857  Focuspot Micro Tip Patches  Dr. Jart+
# 3  combination      black    P442857  Focuspot Micro Tip Patches  Dr. Jart+
# 4          NaN        NaN    P442857  Focuspot Micro Tip Patches  Dr. Jart+
#
#    price_usd
# 0       20.0
# 1       20.0
# 2       20.0
# 3       20.0
# 4       20.0

# %%
reviews_5.head()
# Out:
#    Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 0           0   8554483509       2             0.0          NaN
# 1           1  24710523057       2             0.0     1.000000
# 2           2   8429283179       5             1.0     0.941176
# 3           3   8105185455       1             0.0     0.000000
# 4           4   1515931062       1             0.0     0.000000
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     0                         0                         0
# 1                     2                         0                         2
# 2                    34                         2                        32
# 3                     5                         5                         0
# 4                     7                         7                         0
#
#   submission_time                                        review_text  \
# 0      2023-03-21  This was gifted by Supergoop! in exchange for ...
# 1      2023-03-07  I didn’t like it; too much product comes out w...
# 2      2023-03-01  Y’all….I’m begging for everyone to read instru...
# 3      2023-02-27  I have not figured out how to use this product...
# 4      2023-02-27  I’m at a loss as to how to use this thing!!! C...
#
#                          review_title skin_tone eye_color    skin_type  \
# 0  Nice packaging but easy to overuse     light     brown  combination
# 1           Packaging is not suits le       NaN     brown  combination
# 2                   PLS READ THIS LOL     light     green       normal
# 3                           At a loss       tan     brown  combination
# 4                        NOT for me!!      fair      blue  combination
#
#   hair_color product_id                                       product_name  \
# 0        NaN    P467976  (Re)setting 100% Mineral Powder Sunscreen SPF ...
# 1        NaN    P467976  (Re)setting 100% Mineral Powder Sunscreen SPF ...
# 2      brown    P467976  (Re)setting 100% Mineral Powder Sunscreen SPF ...
# 3      black    P467976  (Re)setting 100% Mineral Powder Sunscreen SPF ...
# 4     blonde    P467976  (Re)setting 100% Mineral Powder Sunscreen SPF ...
#
#    brand_name  price_usd
# 0  Supergoop!       35.0
# 1  Supergoop!       35.0
# 2  Supergoop!       35.0
# 3  Supergoop!       35.0
# 4  Supergoop!       35.0

# %%
reviews_6.head()
# Out:
#    Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 0           0   1945004256       5             1.0     0.000000
# 1           1   5478482359       3             1.0     0.333333
# 2           2  29002209922       5             1.0     1.000000
# 3           3   7391078463       5             1.0     1.000000
# 4           4   1766313888       5             1.0     1.000000
#
#    total_feedback_count  total_neg_feedback_count  total_pos_feedback_count  \
# 0                     2                         2                         0
# 1                     3                         2                         1
# 2                     2                         0                         2
# 3                     2                         0                         2
# 4                    13                         0                        13
#
#   submission_time                                        review_text  \
# 0      2022-12-10  I absolutely L-O-V-E this oil. I have acne pro...
# 1      2021-12-17  I gave this 3 stars because it give me tiny li...
# 2      2021-06-07  Works well as soon as I wash my face and pat d...
# 3      2021-05-21  this oil helped with hydration and breakouts, ...
# 4      2021-03-29  This is my first product review ever so that s...
#
#                        review_title    skin_tone eye_color    skin_type  \
# 0                      A must have!  lightMedium     green  combination
# 1  it keeps oily skin under control    mediumTan     brown         oily
# 2                  Worth the money!  lightMedium     brown          dry
# 3                     best face oil  lightMedium     brown  combination
# 4                    Maskne miracle    mediumTan     brown  combination
#
#   hair_color product_id                                       product_name  \
# 0        NaN    P379064  Lotus Balancing & Hydrating Natural Face Treat...
# 1      black    P379064  Lotus Balancing & Hydrating Natural Face Treat...
# 2      black    P379064  Lotus Balancing & Hydrating Natural Face Treat...
# 3     blonde    P379064  Lotus Balancing & Hydrating Natural Face Treat...
# 4      black    P379064  Lotus Balancing & Hydrating Natural Face Treat...
#
#   brand_name  price_usd
# 0    Clarins       65.0
# 1    Clarins       65.0
# 2    Clarins       65.0
# 3    Clarins       65.0
# 4    Clarins       65.0

# %%
# review shapes of each review dataframe

print(reviews_2.shape)
print(reviews_3.shape)
print(reviews_4.shape)
print(reviews_5.shape)
print(reviews_6.shape)
# Out:
# (206725, 19)
# (206725, 19)
# (116262, 19)
# (119317, 19)
# (49977, 19)

# %%
# concat review dataframes into one

frames = [reviews_2, reviews_3, reviews_4, reviews_5, reviews_6]
reviews = pd.concat(frames)

# %%
print(reviews.shape)
# Out:
# (699006, 19)

# %%
# take a random sample of 50000 rows to work with

reviews = reviews.sample(n=50000)

# %%
print(reviews.shape)
# Out:
# (50000, 19)

# %%
reviews.head()
# Out:
#         Unnamed: 0   author_id  rating  is_recommended  helpfulness  \
# 140270      140270  6967735819       5             1.0      0.93617
# 161905      161905  2154840579       3             0.0          NaN
# 91149        91149  2653437823       3             0.0      0.00000
# 21737        21737  1531781632       5             1.0          NaN
# 18435        18435  6370780822       5             1.0          NaN
#
#         total_feedback_count  total_neg_feedback_count  \
# 140270                   235                        15
# 161905                     0                         0
# 91149                      1                         1
# 21737                      0                         0
# 18435                      0                         0
#
#         total_pos_feedback_count submission_time  \
# 140270                       220      2021-04-30
# 161905                         0      2020-01-09
# 91149                          0      2022-03-17
# 21737                          0      2018-09-20
# 18435                          0      2023-01-23
#
#                                               review_text        review_title  \
# 140270  I have been using this for just under a year (...  A Skincare Staple!
# 161905  I received this product through Influenster to...                 NaN
# 91149   Alright. I’ve used this product multiple times...                 NaN
# 21737   This cream is amazing!! I love it! Makes my sk...              looove
# 18435   This mask was so rejuvenating! It left my skin...             Amazing
#
#         skin_tone eye_color    skin_type hair_color product_id  \
# 140270       fair     brown  combination     blonde    P427412
# 161905  fairLight      blue  combination     blonde    P453824
# 91149       light     brown         oily      black    P442990
# 21737   mediumTan     brown  combination      brown    P426707
# 18435      medium     hazel         oily     auburn    P504064
#
#                                              product_name          brand_name  \
# 140270      Alpha Arbutin 2% + HA Hyperpigmentation Serum        The Ordinary
# 161905                 Vital-E Antioxidant Recovery Cream   Peter Thomas Roth
# 91149   Clean Screen Mineral SPF 30 Mattifying Face Su...  REN Clean Skincare
# 21737                       Hello FAB Coconut Water Cream    First Aid Beauty
# 18435                        Ceramidin Cream-Infused Mask           Dr. Jart+
#
#         price_usd
# 140270       11.1
# 161905       75.0
# 91149        40.0
# 21737        36.0
# 18435        15.0

# %%
# drop uneccesary columns, reset index

reviews.drop(columns=['Unnamed: 0', 'author_id'], inplace=True)
reviews.reset_index(drop=True, inplace=True)

# %%
reviews.head()
# Out:
#    rating  is_recommended  helpfulness  total_feedback_count  \
# 0       5             1.0      0.93617                   235
# 1       3             0.0          NaN                     0
# 2       3             0.0      0.00000                     1
# 3       5             1.0          NaN                     0
# 4       5             1.0          NaN                     0
#
#    total_neg_feedback_count  total_pos_feedback_count submission_time  \
# 0                        15                       220      2021-04-30
# 1                         0                         0      2020-01-09
# 2                         1                         0      2022-03-17
# 3                         0                         0      2018-09-20
# 4                         0                         0      2023-01-23
#
#                                          review_text        review_title  \
# 0  I have been using this for just under a year (...  A Skincare Staple!
# 1  I received this product through Influenster to...                 NaN
# 2  Alright. I’ve used this product multiple times...                 NaN
# 3  This cream is amazing!! I love it! Makes my sk...              looove
# 4  This mask was so rejuvenating! It left my skin...             Amazing
#
#    skin_tone eye_color    skin_type hair_color product_id  \
# 0       fair     brown  combination     blonde    P427412
# 1  fairLight      blue  combination     blonde    P453824
# 2      light     brown         oily      black    P442990
# 3  mediumTan     brown  combination      brown    P426707
# 4     medium     hazel         oily     auburn    P504064
#
#                                         product_name          brand_name  \
# 0      Alpha Arbutin 2% + HA Hyperpigmentation Serum        The Ordinary
# 1                 Vital-E Antioxidant Recovery Cream   Peter Thomas Roth
# 2  Clean Screen Mineral SPF 30 Mattifying Face Su...  REN Clean Skincare
# 3                      Hello FAB Coconut Water Cream    First Aid Beauty
# 4                       Ceramidin Cream-Infused Mask           Dr. Jart+
#
#    price_usd
# 0       11.1
# 1       75.0
# 2       40.0
# 3       36.0
# 4       15.0

# %%
reviews.tail()
# Out:
#        rating  is_recommended  helpfulness  total_feedback_count  \
# 49995       5             1.0          NaN                     0
# 49996       5             1.0     0.000000                     1
# 49997       5             1.0          NaN                     0
# 49998       2             0.0     0.692308                    13
# 49999       4             1.0          NaN                     0
#
#        total_neg_feedback_count  total_pos_feedback_count submission_time  \
# 49995                         0                         0      2023-02-27
# 49996                         1                         0      2022-12-13
# 49997                         0                         0      2017-12-26
# 49998                         4                         9      2021-10-21
# 49999                         0                         0      2022-06-27
#
#                                              review_text  \
# 49995  Gifted by Benefit Cosmetics. Obsessed with thi...
# 49996  I have been using this serum almost 2 weeks no...
# 49997  Buy this right now. You won’t regret it. Why? ...
# 49998  Bought this because it was kind to lashes and ...
# 49999  It’s a good oil/gloss non sticky and stays for...
#
#                    review_title    skin_tone eye_color    skin_type  \
# 49995                   So good        light     brown  combination
# 49996                       NaN          NaN     brown          dry
# 49997  Best Acne Face Wash Ever         fair     hazel          dry
# 49998                       NaN  lightMedium     brown  combination
# 49999                       NaN        light     brown  combination
#
#       hair_color product_id  \
# 49995      black    P505024
# 49996      black    P503726
# 49997      brown    P415667
# 49998      brown    P468637
# 49999      brown    P500307
#
#                                             product_name         brand_name  \
# 49995  The POREfessional Get Unblocked Makeup-Removin...  Benefit Cosmetics
# 49996                      B3 Nice 10% Niacinamide Serum       Sunday Riley
# 49997            EradiKate Daily Cleanser Acne Treatment    Kate Somerville
# 49998            Vinoclean Makeup Removing Cleansing Oil           Caudalie
# 49999  Cherry Treat Conditioning + Strengthening Lip Oil         Fenty Skin
#
#        price_usd
# 49995       39.0
# 49996       65.0
# 49997       44.0
# 49998       30.0
# 49999       24.0

# %%
# save to pickle for EDA use

reviews.to_pickle("reviews.pkl")

# %%
# create a new dataframe for text and sentiment only

reviews_text_only = reviews[['review_text', 'is_recommended']]

# %%
reviews_text_only.head()
# Out:
#                                          review_text  is_recommended
# 0  I have been using this for just under a year (...             1.0
# 1  I received this product through Influenster to...             0.0
# 2  Alright. I’ve used this product multiple times...             0.0
# 3  This cream is amazing!! I love it! Makes my sk...             1.0
# 4  This mask was so rejuvenating! It left my skin...             1.0

# %%
# fix dtypes

reviews_text_only["review_text"] = reviews_text_only["review_text"].values.astype('str')

# %%
# preprocess text - remove punctuation

r = re.compile(r'[^\w\s]+')

reviews_text_only['text_preproc'] = [r.sub('', s) for s in reviews_text_only['review_text'].tolist()]

# %%
# convert to lowercase

reviews_text_only['text_preproc'] = reviews_text_only['text_preproc'].str.lower()

# %%
# reorder dataframe

reviews_text_only = reviews_text_only[['review_text', 'text_preproc', 'is_recommended']]

# %%
reviews_text_only.head()
# Out:
#                                          review_text  \
# 0  I have been using this for just under a year (...
# 1  I received this product through Influenster to...
# 2  Alright. I’ve used this product multiple times...
# 3  This cream is amazing!! I love it! Makes my sk...
# 4  This mask was so rejuvenating! It left my skin...
#
#                                         text_preproc  is_recommended
# 0  i have been using this for just under a year i...             1.0
# 1  i received this product through influenster to...             0.0
# 2  alright ive used this product multiple times a...             0.0
# 3  this cream is amazing i love it makes my skin ...             1.0
# 4  this mask was so rejuvenating it left my skin ...             1.0

# %%
reviews_text_only.tail()
# Out:
#                                              review_text  \
# 49995  Gifted by Benefit Cosmetics. Obsessed with thi...
# 49996  I have been using this serum almost 2 weeks no...
# 49997  Buy this right now. You won’t regret it. Why? ...
# 49998  Bought this because it was kind to lashes and ...
# 49999  It’s a good oil/gloss non sticky and stays for...
#
#                                             text_preproc  is_recommended
# 49995  gifted by benefit cosmetics obsessed with this...             1.0
# 49996  i have been using this serum almost 2 weeks no...             1.0
# 49997  buy this right now you wont regret it why as s...             1.0
# 49998  bought this because it was kind to lashes and ...             0.0
# 49999  its a good oilgloss non sticky and stays for a...             1.0

# %%
# save to pickle

reviews_text_only.to_pickle("reviews_text_only.pkl")
